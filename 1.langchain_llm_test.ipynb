# %%
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
# import os
# OPENAI_API_KEY
from langchain_openai import ChatOpenAI
# api_key = os.getenv("OPENAI_KEY")

llm = ChatOpenAI(model="gpt-4o-mini", temperature=0)
# api_key=api_key

# %%
ai_message = llm.invoke("인프런에 어떤 강의가 있나요?")

# %%
ai_message.content
# Out:
# '인프런에는 다양한 분야의 강의가 있습니다. 주요 카테고리로는 프로그래밍, 비즈니스, 마케팅, 투자 및 재무, 외국어 등이 있습니다. 특히 프로그래밍 분야에서는 Python, 자바, 스프링 프레임워크, 리액트 등 다양한 강의가 제공되고 있습니다. 또한 인프런에서는 전문가들이 직접 강의를 진행하므로 신뢰성이 높고 실용적인 내용을 학습할 수 있습니다. 원하는 분야의 강의를 찾아보시면 도움이 될 것입니다.'
