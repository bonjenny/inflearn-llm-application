# %%
# %pip install python-dotenv langchain-community
# Out:
# Requirement already satisfied: python-dotenv in c:\users\bonje\anaconda3\envs\inflearn-llm-application\lib\site-packages (1.2.1)
# Collecting langchain-community
#   Using cached langchain_community-0.4.1-py3-none-any.whl.metadata (3.0 kB)
# Requirement already satisfied: langchain-core<2.0.0,>=1.0.1 in c:\users\bonje\anaconda3\envs\inflearn-llm-application\lib\site-packages (from langchain-community) (1.2.17)
# Requirement already satisfied: langchain-classic<2.0.0,>=1.0.0 in c:\users\bonje\anaconda3\envs\inflearn-llm-application\lib\site-packages (from langchain-community) (1.0.2)
# Requirement already satisfied: SQLAlchemy<3.0.0,>=1.4.0 in c:\users\bonje\anaconda3\envs\inflearn-llm-application\lib\site-packages (from langchain-community) (2.0.48)
# Requirement already satisfied: requests<3.0.0,>=2.32.5 in c:\users\bonje\anaconda3\envs\inflearn-llm-application\lib\site-packages (from langchain-community) (2.32.5)
# Requirement already satisfied: PyYAML<7.0.0,>=5.3.0 in c:\users\bonje\anaconda3\envs\inflearn-llm-application\lib\site-packages (from langchain-community) (6.0.3)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in c:\users\bonje\anaconda3\envs\inflearn-llm-application\lib\site-packages (from langchain-community) (3.13.3)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in c:\users\bonje\anaconda3\envs\inflearn-llm-application\lib\site-packages (from langchain-community) (9.1.4)
# Requirement already satisfied: dataclasses-json<0.7.0,>=0.6.7 in c:\users\bonje\anaconda3\envs\inflearn-llm-application\lib\site-packages (from langchain-community) (0.6.7)
# Requirement already satisfied: pydantic-settings<3.0.0,>=2.10.1 in c:\users\bonje\anaconda3\envs\inflearn-llm-application\lib\site-packages (from langchain-community) (2.13.1)
# Requirement already satisfied: langsmith<1.0.0,>=0.1.125 in c:\users\bonje\anaconda3\envs\inflearn-llm-application\lib\site-packages (from langchain-community) (0.7.4)
# Requirement already satisfied: httpx-sse<1.0.0,>=0.4.0 in c:\users\bonje\anaconda3\envs\inflearn-llm-application\lib\site-packages (from langchain-community) (0.4.3)
# Requirement already satisfied: numpy>=1.26.2 in c:\users\bonje\anaconda3\envs\inflearn-llm-application\lib\site-packages (from langchain-community) (2.2.6)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in c:\users\bonje\anaconda3\envs\inflearn-llm-application\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in c:\users\bonje\anaconda3\envs\inflearn-llm-application\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.4.0)
# Requirement already satisfied: async-timeout<6.0,>=4.0 in c:\users\bonje\anaconda3\envs\inflearn-llm-application\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (4.0.3)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\bonje\anaconda3\envs\inflearn-llm-application\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (25.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\bonje\anaconda3\envs\inflearn-llm-application\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\bonje\anaconda3\envs\inflearn-llm-application\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (6.7.1)
# Requirement already satisfied: propcache>=0.2.0 in c:\users\bonje\anaconda3\envs\inflearn-llm-application\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in c:\users\bonje\anaconda3\envs\inflearn-llm-application\lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.23.0)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in c:\users\bonje\anaconda3\envs\inflearn-llm-application\lib\site-packages (from dataclasses-json<0.7.0,>=0.6.7->langchain-community) (3.26.2)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in c:\users\bonje\anaconda3\envs\inflearn-llm-application\lib\site-packages (from dataclasses-json<0.7.0,>=0.6.7->langchain-community) (0.9.0)
# Requirement already satisfied: langchain-text-splitters<2.0.0,>=1.1.0 in c:\users\bonje\anaconda3\envs\inflearn-llm-application\lib\site-packages (from langchain-classic<2.0.0,>=1.0.0->langchain-community) (1.1.1)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in c:\users\bonje\anaconda3\envs\inflearn-llm-application\lib\site-packages (from langchain-classic<2.0.0,>=1.0.0->langchain-community) (2.12.5)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in c:\users\bonje\anaconda3\envs\inflearn-llm-application\lib\site-packages (from langchain-core<2.0.0,>=1.0.1->langchain-community) (1.33)
# Requirement already satisfied: packaging>=23.2.0 in c:\users\bonje\anaconda3\envs\inflearn-llm-application\lib\site-packages (from langchain-core<2.0.0,>=1.0.1->langchain-community) (25.0)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in c:\users\bonje\anaconda3\envs\inflearn-llm-application\lib\site-packages (from langchain-core<2.0.0,>=1.0.1->langchain-community) (4.15.0)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in c:\users\bonje\anaconda3\envs\inflearn-llm-application\lib\site-packages (from langchain-core<2.0.0,>=1.0.1->langchain-community) (0.14.0)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\bonje\anaconda3\envs\inflearn-llm-application\lib\site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.0.1->langchain-community) (3.0.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\users\bonje\anaconda3\envs\inflearn-llm-application\lib\site-packages (from langsmith<1.0.0,>=0.1.125->langchain-community) (0.28.1)
# Requirement already satisfied: orjson>=3.9.14 in c:\users\bonje\anaconda3\envs\inflearn-llm-application\lib\site-packages (from langsmith<1.0.0,>=0.1.125->langchain-community) (3.11.7)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in c:\users\bonje\anaconda3\envs\inflearn-llm-application\lib\site-packages (from langsmith<1.0.0,>=0.1.125->langchain-community) (1.0.0)
# Requirement already satisfied: xxhash>=3.0.0 in c:\users\bonje\anaconda3\envs\inflearn-llm-application\lib\site-packages (from langsmith<1.0.0,>=0.1.125->langchain-community) (3.6.0)
# Requirement already satisfied: zstandard>=0.23.0 in c:\users\bonje\anaconda3\envs\inflearn-llm-application\lib\site-packages (from langsmith<1.0.0,>=0.1.125->langchain-community) (0.25.0)
# Requirement already satisfied: anyio in c:\users\bonje\anaconda3\envs\inflearn-llm-application\lib\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.1.125->langchain-community) (4.12.1)
# Requirement already satisfied: certifi in c:\users\bonje\anaconda3\envs\inflearn-llm-application\lib\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.1.125->langchain-community) (2026.1.4)
# Requirement already satisfied: httpcore==1.* in c:\users\bonje\anaconda3\envs\inflearn-llm-application\lib\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.1.125->langchain-community) (1.0.9)
# Requirement already satisfied: idna in c:\users\bonje\anaconda3\envs\inflearn-llm-application\lib\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.1.125->langchain-community) (3.11)
# Requirement already satisfied: h11>=0.16 in c:\users\bonje\anaconda3\envs\inflearn-llm-application\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<1.0.0,>=0.1.125->langchain-community) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\bonje\anaconda3\envs\inflearn-llm-application\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain-classic<2.0.0,>=1.0.0->langchain-community) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in c:\users\bonje\anaconda3\envs\inflearn-llm-application\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain-classic<2.0.0,>=1.0.0->langchain-community) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in c:\users\bonje\anaconda3\envs\inflearn-llm-application\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain-classic<2.0.0,>=1.0.0->langchain-community) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\bonje\anaconda3\envs\inflearn-llm-application\lib\site-packages (from requests<3.0.0,>=2.32.5->langchain-community) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\bonje\anaconda3\envs\inflearn-llm-application\lib\site-packages (from requests<3.0.0,>=2.32.5->langchain-community) (2.6.3)
# Requirement already satisfied: greenlet>=1 in c:\users\bonje\anaconda3\envs\inflearn-llm-application\lib\site-packages (from SQLAlchemy<3.0.0,>=1.4.0->langchain-community) (3.3.2)
# Requirement already satisfied: mypy-extensions>=0.3.0 in c:\users\bonje\anaconda3\envs\inflearn-llm-application\lib\site-packages (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7.0,>=0.6.7->langchain-community) (1.1.0)
# Requirement already satisfied: exceptiongroup>=1.0.2 in c:\users\bonje\anaconda3\envs\inflearn-llm-application\lib\site-packages (from anyio->httpx<1,>=0.23.0->langsmith<1.0.0,>=0.1.125->langchain-community) (1.3.1)
# Using cached langchain_community-0.4.1-py3-none-any.whl (2.5 MB)
# Installing collected packages: langchain-community
# Successfully installed langchain-community-0.4.1
# Note: you may need to restart the kernel to use updated packages.

# %%
# 2. LLM 답변 생성
# - `ChatOllama` 를 활용한 LLM 답변 생성

# %%
import os
from langchain_upstage import ChatUpstage

llm = ChatUpstage(api_key=os.getenv("UPSTAGE_API_KEY"))
ai_message = llm.invoke("인프런에 어떤 강의가 있나요?")
ai_message.content
# Out:
# Requirement already satisfied: python-dotenv in c:\users\bonje\anaconda3\envs\inflearn-llm-application\lib\site-packages (1.2.1)
# Collecting langchain-community
#   Downloading langchain_community-0.4.1-py3-none-any.whl.metadata (3.0 kB)
# Requirement already satisfied: langchain-core<2.0.0,>=1.0.1 in c:\users\bonje\anaconda3\envs\inflearn-llm-application\lib\site-packages (from langchain-community) (1.2.13)
# Collecting langchain-classic<2.0.0,>=1.0.0 (from langchain-community)
#   Downloading langchain_classic-1.0.2-py3-none-any.whl.metadata (4.8 kB)
# Collecting SQLAlchemy<3.0.0,>=1.4.0 (from langchain-community)
#   Downloading sqlalchemy-2.0.48-cp310-cp310-win_amd64.whl.metadata (9.8 kB)
# Requirement already satisfied: requests<3.0.0,>=2.32.5 in c:\users\bonje\anaconda3\envs\inflearn-llm-application\lib\site-packages (from langchain-community) (2.32.5)
# Requirement already satisfied: PyYAML<7.0.0,>=5.3.0 in c:\users\bonje\anaconda3\envs\inflearn-llm-application\lib\site-packages (from langchain-community) (6.0.3)
# Collecting aiohttp<4.0.0,>=3.8.3 (from langchain-community)
#   Downloading aiohttp-3.13.3-cp310-cp310-win_amd64.whl.metadata (8.4 kB)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in c:\users\bonje\anaconda3\envs\inflearn-llm-application\lib\site-packages (from langchain-community) (9.1.4)
# Collecting dataclasses-json<0.7.0,>=0.6.7 (from langchain-community)
#   Downloading dataclasses_json-0.6.7-py3-none-any.whl.metadata (25 kB)
# Collecting pydantic-settings<3.0.0,>=2.10.1 (from langchain-community)
#   Downloading pydantic_settings-2.13.1-py3-none-any.whl.metadata (3.4 kB)
# Requirement already satisfied: langsmith<1.0.0,>=0.1.125 in c:\users\bonje\anaconda3\envs\inflearn-llm-application\lib\site-packages (from langchain-community) (0.7.4)
# Collecting httpx-sse<1.0.0,>=0.4.0 (from langchain-community)
#   Downloading httpx_sse-0.4.3-py3-none-any.whl.metadata (9.7 kB)
# Collecting numpy>=1.26.2 (from langchain-community)
#   Downloading numpy-2.2.6-cp310-cp310-win_amd64.whl.metadata (60 kB)
# Collecting aiohappyeyeballs>=2.5.0 (from aiohttp<4.0.0,>=3.8.3->langchain-community)
#   Downloading aiohappyeyeballs-2.6.1-py3-none-any.whl.metadata (5.9 kB)
# Collecting aiosignal>=1.4.0 (from aiohttp<4.0.0,>=3.8.3->langchain-community)
#   Downloading aiosignal-1.4.0-py3-none-any.whl.metadata (3.7 kB)
# Collecting async-timeout<6.0,>=4.0 (from aiohttp<4.0.0,>=3.8.3->langchain-community)
#   Downloading async_timeout-5.0.1-py3-none-any.whl.metadata (5.1 kB)
# Collecting attrs>=17.3.0 (from aiohttp<4.0.0,>=3.8.3->langchain-community)
#   Downloading attrs-25.4.0-py3-none-any.whl.metadata (10 kB)
# Collecting frozenlist>=1.1.1 (from aiohttp<4.0.0,>=3.8.3->langchain-community)
#   Downloading frozenlist-1.8.0-cp310-cp310-win_amd64.whl.metadata (21 kB)
# Collecting multidict<7.0,>=4.5 (from aiohttp<4.0.0,>=3.8.3->langchain-community)
#   Downloading multidict-6.7.1-cp310-cp310-win_amd64.whl.metadata (5.5 kB)
# Collecting propcache>=0.2.0 (from aiohttp<4.0.0,>=3.8.3->langchain-community)
#   Downloading propcache-0.4.1-cp310-cp310-win_amd64.whl.metadata (14 kB)
# Collecting yarl<2.0,>=1.17.0 (from aiohttp<4.0.0,>=3.8.3->langchain-community)
#   Downloading yarl-1.23.0-cp310-cp310-win_amd64.whl.metadata (82 kB)
# Collecting marshmallow<4.0.0,>=3.18.0 (from dataclasses-json<0.7.0,>=0.6.7->langchain-community)
#   Downloading marshmallow-3.26.2-py3-none-any.whl.metadata (7.3 kB)
# Collecting typing-inspect<1,>=0.4.0 (from dataclasses-json<0.7.0,>=0.6.7->langchain-community)
#   Downloading typing_inspect-0.9.0-py3-none-any.whl.metadata (1.5 kB)
# Collecting async-timeout<6.0,>=4.0 (from aiohttp<4.0.0,>=3.8.3->langchain-community)
#   Downloading async_timeout-4.0.3-py3-none-any.whl.metadata (4.2 kB)
# Collecting langchain-core<2.0.0,>=1.0.1 (from langchain-community)
#   Downloading langchain_core-1.2.17-py3-none-any.whl.metadata (4.4 kB)
# Collecting langchain-text-splitters<2.0.0,>=1.1.0 (from langchain-classic<2.0.0,>=1.0.0->langchain-community)
#   Downloading langchain_text_splitters-1.1.1-py3-none-any.whl.metadata (3.3 kB)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in c:\users\bonje\anaconda3\envs\inflearn-llm-application\lib\site-packages (from langchain-classic<2.0.0,>=1.0.0->langchain-community) (2.12.5)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in c:\users\bonje\anaconda3\envs\inflearn-llm-application\lib\site-packages (from langchain-core<2.0.0,>=1.0.1->langchain-community) (1.33)
# Requirement already satisfied: packaging>=23.2.0 in c:\users\bonje\anaconda3\envs\inflearn-llm-application\lib\site-packages (from langchain-core<2.0.0,>=1.0.1->langchain-community) (25.0)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in c:\users\bonje\anaconda3\envs\inflearn-llm-application\lib\site-packages (from langchain-core<2.0.0,>=1.0.1->langchain-community) (4.15.0)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in c:\users\bonje\anaconda3\envs\inflearn-llm-application\lib\site-packages (from langchain-core<2.0.0,>=1.0.1->langchain-community) (0.14.0)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\bonje\anaconda3\envs\inflearn-llm-application\lib\site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.0.1->langchain-community) (3.0.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\users\bonje\anaconda3\envs\inflearn-llm-application\lib\site-packages (from langsmith<1.0.0,>=0.1.125->langchain-community) (0.28.1)
# Requirement already satisfied: orjson>=3.9.14 in c:\users\bonje\anaconda3\envs\inflearn-llm-application\lib\site-packages (from langsmith<1.0.0,>=0.1.125->langchain-community) (3.11.7)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in c:\users\bonje\anaconda3\envs\inflearn-llm-application\lib\site-packages (from langsmith<1.0.0,>=0.1.125->langchain-community) (1.0.0)
# Requirement already satisfied: xxhash>=3.0.0 in c:\users\bonje\anaconda3\envs\inflearn-llm-application\lib\site-packages (from langsmith<1.0.0,>=0.1.125->langchain-community) (3.6.0)
# Requirement already satisfied: zstandard>=0.23.0 in c:\users\bonje\anaconda3\envs\inflearn-llm-application\lib\site-packages (from langsmith<1.0.0,>=0.1.125->langchain-community) (0.25.0)
# Requirement already satisfied: anyio in c:\users\bonje\anaconda3\envs\inflearn-llm-application\lib\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.1.125->langchain-community) (4.12.1)
# Requirement already satisfied: certifi in c:\users\bonje\anaconda3\envs\inflearn-llm-application\lib\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.1.125->langchain-community) (2026.1.4)
# Requirement already satisfied: httpcore==1.* in c:\users\bonje\anaconda3\envs\inflearn-llm-application\lib\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.1.125->langchain-community) (1.0.9)
# Requirement already satisfied: idna in c:\users\bonje\anaconda3\envs\inflearn-llm-application\lib\site-packages (from httpx<1,>=0.23.0->langsmith<1.0.0,>=0.1.125->langchain-community) (3.11)
# Requirement already satisfied: h11>=0.16 in c:\users\bonje\anaconda3\envs\inflearn-llm-application\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<1.0.0,>=0.1.125->langchain-community) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\bonje\anaconda3\envs\inflearn-llm-application\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain-classic<2.0.0,>=1.0.0->langchain-community) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in c:\users\bonje\anaconda3\envs\inflearn-llm-application\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain-classic<2.0.0,>=1.0.0->langchain-community) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in c:\users\bonje\anaconda3\envs\inflearn-llm-application\lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain-classic<2.0.0,>=1.0.0->langchain-community) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\bonje\anaconda3\envs\inflearn-llm-application\lib\site-packages (from requests<3.0.0,>=2.32.5->langchain-community) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\bonje\anaconda3\envs\inflearn-llm-application\lib\site-packages (from requests<3.0.0,>=2.32.5->langchain-community) (2.6.3)
# Collecting greenlet>=1 (from SQLAlchemy<3.0.0,>=1.4.0->langchain-community)
#   Downloading greenlet-3.3.2-cp310-cp310-win_amd64.whl.metadata (3.8 kB)
# Collecting mypy-extensions>=0.3.0 (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7.0,>=0.6.7->langchain-community)
#   Downloading mypy_extensions-1.1.0-py3-none-any.whl.metadata (1.1 kB)
# Requirement already satisfied: exceptiongroup>=1.0.2 in c:\users\bonje\anaconda3\envs\inflearn-llm-application\lib\site-packages (from anyio->httpx<1,>=0.23.0->langsmith<1.0.0,>=0.1.125->langchain-community) (1.3.1)
# Downloading langchain_community-0.4.1-py3-none-any.whl (2.5 MB)
#    ---------------------------------------- 0.0/2.5 MB ? eta -:--:--
#    -------------------- ------------------- 1.3/2.5 MB 6.7 MB/s eta 0:00:01
#    --------------------------------- ------ 2.1/2.5 MB 5.9 MB/s eta 0:00:01
#    ---------------------------------------- 2.5/2.5 MB 4.7 MB/s  0:00:00
# Downloading aiohttp-3.13.3-cp310-cp310-win_amd64.whl (456 kB)
# Downloading dataclasses_json-0.6.7-py3-none-any.whl (28 kB)
# Downloading httpx_sse-0.4.3-py3-none-any.whl (9.0 kB)
# Downloading langchain_classic-1.0.2-py3-none-any.whl (1.0 MB)
#    ---------------------------------------- 0.0/1.0 MB ? eta -:--:--
#    -------------------- ------------------- 0.5/1.0 MB 2.1 MB/s eta 0:00:01
#    ---------------------------------------- 1.0/1.0 MB 3.3 MB/s  0:00:00
# Downloading async_timeout-4.0.3-py3-none-any.whl (5.7 kB)
# Downloading langchain_core-1.2.17-py3-none-any.whl (502 kB)
# Downloading langchain_text_splitters-1.1.1-py3-none-any.whl (35 kB)
# Downloading marshmallow-3.26.2-py3-none-any.whl (50 kB)
# Downloading multidict-6.7.1-cp310-cp310-win_amd64.whl (46 kB)
# Downloading pydantic_settings-2.13.1-py3-none-any.whl (58 kB)
# Downloading sqlalchemy-2.0.48-cp310-cp310-win_amd64.whl (2.1 MB)
#    ---------------------------------------- 0.0/2.1 MB ? eta -:--:--
#    -------------- ------------------------- 0.8/2.1 MB 5.6 MB/s eta 0:00:01
#    ---------------------------------------- 2.1/2.1 MB 6.7 MB/s  0:00:00
# Downloading typing_inspect-0.9.0-py3-none-any.whl (8.8 kB)
# Downloading yarl-1.23.0-cp310-cp310-win_amd64.whl (87 kB)
# Downloading aiohappyeyeballs-2.6.1-py3-none-any.whl (15 kB)
# Downloading aiosignal-1.4.0-py3-none-any.whl (7.5 kB)
# Downloading attrs-25.4.0-py3-none-any.whl (67 kB)
# Downloading frozenlist-1.8.0-cp310-cp310-win_amd64.whl (43 kB)
# Downloading greenlet-3.3.2-cp310-cp310-win_amd64.whl (230 kB)
# Downloading mypy_extensions-1.1.0-py3-none-any.whl (5.0 kB)
# Downloading numpy-2.2.6-cp310-cp310-win_amd64.whl (12.9 MB)
#    ---------------------------------------- 0.0/12.9 MB ? eta -:--:--
#     --------------------------------------- 0.3/12.9 MB ? eta -:--:--
#    ---- ----------------------------------- 1.3/12.9 MB 4.2 MB/s eta 0:00:03
#    -------- ------------------------------- 2.9/12.9 MB 5.2 MB/s eta 0:00:02
#    ------------ --------------------------- 3.9/12.9 MB 5.2 MB/s eta 0:00:02
#    ---------------- ----------------------- 5.2/12.9 MB 5.4 MB/s eta 0:00:02
#    ------------------ --------------------- 6.0/12.9 MB 5.2 MB/s eta 0:00:02
#    -------------------- ------------------- 6.6/12.9 MB 4.9 MB/s eta 0:00:02
#    ------------------------ --------------- 7.9/12.9 MB 4.9 MB/s eta 0:00:02
#    -------------------------- ------------- 8.4/12.9 MB 4.7 MB/s eta 0:00:01
#    ------------------------------ --------- 10.0/12.9 MB 5.0 MB/s eta 0:00:01
#    ---------------------------------- ----- 11.3/12.9 MB 5.0 MB/s eta 0:00:01
#    ---------------------------------------  12.8/12.9 MB 5.2 MB/s eta 0:00:01
#    ---------------------------------------- 12.9/12.9 MB 5.2 MB/s  0:00:02
# Downloading propcache-0.4.1-cp310-cp310-win_amd64.whl (41 kB)
# Installing collected packages: propcache, numpy, mypy-extensions, multidict, marshmallow, httpx-sse, greenlet, frozenlist, attrs, async-timeout, aiohappyeyeballs, yarl, typing-inspect, SQLAlchemy, aiosignal, pydantic-settings, dataclasses-json, aiohttp, langchain-core, langchain-text-splitters, langchain-classic, langchain-community
#
#    - --------------------------------------  1/22 [numpy]
#    - --------------------------------------  1/22 [numpy]
#    - --------------------------------------  1/22 [numpy]
#    - --------------------------------------  1/22 [numpy]
#    - --------------------------------------  1/22 [numpy]
#    - --------------------------------------  1/22 [numpy]
#    - --------------------------------------  1/22 [numpy]
#    - --------------------------------------  1/22 [numpy]
#    - --------------------------------------  1/22 [numpy]
#    - --------------------------------------  1/22 [numpy]
#    - --------------------------------------  1/22 [numpy]
#    - --------------------------------------  1/22 [numpy]
#    - --------------------------------------  1/22 [numpy]
#    - --------------------------------------  1/22 [numpy]
#    - --------------------------------------  1/22 [numpy]
#    - --------------------------------------  1/22 [numpy]
#    - --------------------------------------  1/22 [numpy]
#    - --------------------------------------  1/22 [numpy]
#    - --------------------------------------  1/22 [numpy]
#    - --------------------------------------  1/22 [numpy]
#    - --------------------------------------  1/22 [numpy]
#    - --------------------------------------  1/22 [numpy]
#    - --------------------------------------  1/22 [numpy]
#    - --------------------------------------  1/22 [numpy]
#    - --------------------------------------  1/22 [numpy]
#    - --------------------------------------  1/22 [numpy]
#    - --------------------------------------  1/22 [numpy]
#    - --------------------------------------  1/22 [numpy]
#    - --------------------------------------  1/22 [numpy]
#    - --------------------------------------  1/22 [numpy]
#    - --------------------------------------  1/22 [numpy]
#    - --------------------------------------  1/22 [numpy]
#    - --------------------------------------  1/22 [numpy]
#    - --------------------------------------  1/22 [numpy]
#    - --------------------------------------  1/22 [numpy]
#    - --------------------------------------  1/22 [numpy]
#    - --------------------------------------  1/22 [numpy]
#    - --------------------------------------  1/22 [numpy]
#    - --------------------------------------  1/22 [numpy]
#    - --------------------------------------  1/22 [numpy]
#    - --------------------------------------  1/22 [numpy]
#    ------- --------------------------------  4/22 [marshmallow]
#    ---------- -----------------------------  6/22 [greenlet]
#    ---------- -----------------------------  6/22 [greenlet]
#    ------------ ---------------------------  7/22 [frozenlist]
#    -------------- -------------------------  8/22 [attrs]
#    -------------- -------------------------  8/22 [attrs]
#    ------------------ --------------------- 10/22 [aiohappyeyeballs]
#    -------------------- ------------------- 11/22 [yarl]
#    --------------------- ------------------ 12/22 [typing-inspect]
#    ----------------------- ---------------- 13/22 [SQLAlchemy]
#    ----------------------- ---------------- 13/22 [SQLAlchemy]
#    ----------------------- ---------------- 13/22 [SQLAlchemy]
#    ----------------------- ---------------- 13/22 [SQLAlchemy]
#    ----------------------- ---------------- 13/22 [SQLAlchemy]
#    ----------------------- ---------------- 13/22 [SQLAlchemy]
#    ----------------------- ---------------- 13/22 [SQLAlchemy]
#    ----------------------- ---------------- 13/22 [SQLAlchemy]
#    ----------------------- ---------------- 13/22 [SQLAlchemy]
#    ----------------------- ---------------- 13/22 [SQLAlchemy]
#    ----------------------- ---------------- 13/22 [SQLAlchemy]
#    ----------------------- ---------------- 13/22 [SQLAlchemy]
#    ----------------------- ---------------- 13/22 [SQLAlchemy]
#    ----------------------- ---------------- 13/22 [SQLAlchemy]
#    ----------------------- ---------------- 13/22 [SQLAlchemy]
#    ----------------------- ---------------- 13/22 [SQLAlchemy]
#    ----------------------- ---------------- 13/22 [SQLAlchemy]
#    ----------------------- ---------------- 13/22 [SQLAlchemy]
#    ----------------------- ---------------- 13/22 [SQLAlchemy]
#    ----------------------- ---------------- 13/22 [SQLAlchemy]
#    ----------------------- ---------------- 13/22 [SQLAlchemy]
#    ----------------------- ---------------- 13/22 [SQLAlchemy]
#    --------------------------- ------------ 15/22 [pydantic-settings]
#    ----------------------------- ---------- 16/22 [dataclasses-json]
#    ------------------------------ --------- 17/22 [aiohttp]
#    ------------------------------ --------- 17/22 [aiohttp]
#    ------------------------------ --------- 17/22 [aiohttp]
#    ------------------------------ --------- 17/22 [aiohttp]
#    ------------------------------ --------- 17/22 [aiohttp]
#   Attempting uninstall: langchain-core
#    ------------------------------ --------- 17/22 [aiohttp]
#     Found existing installation: langchain-core 1.2.13
#    ------------------------------ --------- 17/22 [aiohttp]
#     Uninstalling langchain-core-1.2.13:
#    ------------------------------ --------- 17/22 [aiohttp]
#    -------------------------------- ------- 18/22 [langchain-core]
#       Successfully uninstalled langchain-core-1.2.13
#    -------------------------------- ------- 18/22 [langchain-core]
#    -------------------------------- ------- 18/22 [langchain-core]
#    -------------------------------- ------- 18/22 [langchain-core]
#    -------------------------------- ------- 18/22 [langchain-core]
#    -------------------------------- ------- 18/22 [langchain-core]
#    -------------------------------- ------- 18/22 [langchain-core]
#    -------------------------------- ------- 18/22 [langchain-core]
#    -------------------------------- ------- 18/22 [langchain-core]
#    -------------------------------- ------- 18/22 [langchain-core]
#    -------------------------------- ------- 18/22 [langchain-core]
#    -------------------------------- ------- 18/22 [langchain-core]
#    -------------------------------- ------- 18/22 [langchain-core]
#    -------------------------------- ------- 18/22 [langchain-core]
#    -------------------------------- ------- 18/22 [langchain-core]
#    ------------------------------------ --- 20/22 [langchain-classic]
#    ------------------------------------ --- 20/22 [langchain-classic]
#    ------------------------------------ --- 20/22 [langchain-classic]
#    ------------------------------------ --- 20/22 [langchain-classic]
#    ------------------------------------ --- 20/22 [langchain-classic]
#    ------------------------------------ --- 20/22 [langchain-classic]
#    ------------------------------------ --- 20/22 [langchain-classic]
#    ------------------------------------ --- 20/22 [langchain-classic]
#    ------------------------------------ --- 20/22 [langchain-classic]
#    ------------------------------------ --- 20/22 [langchain-classic]
#    ------------------------------------ --- 20/22 [langchain-classic]
#    ------------------------------------ --- 20/22 [langchain-classic]
#    ------------------------------------ --- 20/22 [langchain-classic]
#    ------------------------------------ --- 20/22 [langchain-classic]
#    ------------------------------------ --- 20/22 [langchain-classic]
#    ------------------------------------ --- 20/22 [langchain-classic]
#    ------------------------------------ --- 20/22 [langchain-classic]
#    ------------------------------------ --- 20/22 [langchain-classic]
#    ------------------------------------ --- 20/22 [langchain-classic]
#    ------------------------------------ --- 20/22 [langchain-classic]
#    ------------------------------------ --- 20/22 [langchain-classic]
#    ------------------------------------ --- 20/22 [langchain-classic]
#    ------------------------------------ --- 20/22 [langchain-classic]
#    ------------------------------------ --- 20/22 [langchain-classic]
#    ------------------------------------ --- 20/22 [langchain-classic]
#    ------------------------------------ --- 20/22 [langchain-classic]
#    ------------------------------------ --- 20/22 [langchain-classic]
#    ------------------------------------ --- 20/22 [langchain-classic]
#    ------------------------------------ --- 20/22 [langchain-classic]
#    ------------------------------------ --- 20/22 [langchain-classic]
#    ------------------------------------ --- 20/22 [langchain-classic]
#    ------------------------------------ --- 20/22 [langchain-classic]
#    ------------------------------------ --- 20/22 [langchain-classic]
#    ------------------------------------ --- 20/22 [langchain-classic]
#    ------------------------------------ --- 20/22 [langchain-classic]
#    ------------------------------------ --- 20/22 [langchain-classic]
#    ------------------------------------ --- 20/22 [langchain-classic]
#    ------------------------------------ --- 20/22 [langchain-classic]
#    ------------------------------------ --- 20/22 [langchain-classic]
#    ------------------------------------ --- 20/22 [langchain-classic]
#    ------------------------------------ --- 20/22 [langchain-classic]
#    ------------------------------------ --- 20/22 [langchain-classic]
#    ------------------------------------ --- 20/22 [langchain-classic]
#    ------------------------------------ --- 20/22 [langchain-classic]
#    ------------------------------------ --- 20/22 [langchain-classic]
#    ------------------------------------ --- 20/22 [langchain-classic]
#    ------------------------------------ --- 20/22 [langchain-classic]
#    ------------------------------------ --- 20/22 [langchain-classic]
#    ------------------------------------ --- 20/22 [langchain-classic]
#    ------------------------------------ --- 20/22 [langchain-classic]
#    ------------------------------------ --- 20/22 [langchain-classic]
#    ------------------------------------ --- 20/22 [langchain-classic]
#    ------------------------------------ --- 20/22 [langchain-classic]
#    ------------------------------------ --- 20/22 [langchain-classic]
#    ------------------------------------ --- 20/22 [langchain-classic]
#    ------------------------------------ --- 20/22 [langchain-classic]
#    ------------------------------------ --- 20/22 [langchain-classic]
#    ------------------------------------ --- 20/22 [langchain-classic]
#    ------------------------------------ --- 20/22 [langchain-classic]
#    ------------------------------------ --- 20/22 [langchain-classic]
#    ------------------------------------ --- 20/22 [langchain-classic]
#    ------------------------------------ --- 20/22 [langchain-classic]
#    ------------------------------------ --- 20/22 [langchain-classic]
#    ------------------------------------ --- 20/22 [langchain-classic]
#    ------------------------------------ --- 20/22 [langchain-classic]
#    ------------------------------------ --- 20/22 [langchain-classic]
#    ------------------------------------ --- 20/22 [langchain-classic]
#    ------------------------------------ --- 20/22 [langchain-classic]
#    ------------------------------------ --- 20/22 [langchain-classic]
#    ------------------------------------ --- 20/22 [langchain-classic]
#    ------------------------------------ --- 20/22 [langchain-classic]
#    ------------------------------------ --- 20/22 [langchain-classic]
#    ------------------------------------ --- 20/22 [langchain-classic]
#    ------------------------------------ --- 20/22 [langchain-classic]
#    -------------------------------------- - 21/22 [langchain-community]
#    -------------------------------------- - 21/22 [langchain-community]
#    -------------------------------------- - 21/22 [langchain-community]
#    -------------------------------------- - 21/22 [langchain-community]
#    -------------------------------------- - 21/22 [langchain-community]
#    -------------------------------------- - 21/22 [langchain-community]
#    -------------------------------------- - 21/22 [langchain-community]
#    -------------------------------------- - 21/22 [langchain-community]
#    -------------------------------------- - 21/22 [langchain-community]
#    -------------------------------------- - 21/22 [langchain-community]
#    -------------------------------------- - 21/22 [langchain-community]
#    -------------------------------------- - 21/22 [langchain-community]
#    -------------------------------------- - 21/22 [langchain-community]
#    -------------------------------------- - 21/22 [langchain-community]
#    -------------------------------------- - 21/22 [langchain-community]
#    -------------------------------------- - 21/22 [langchain-community]
#    -------------------------------------- - 21/22 [langchain-community]
#    -------------------------------------- - 21/22 [langchain-community]
#    -------------------------------------- - 21/22 [langchain-community]
#    -------------------------------------- - 21/22 [langchain-community]
#    -------------------------------------- - 21/22 [langchain-community]
#    -------------------------------------- - 21/22 [langchain-community]
#    -------------------------------------- - 21/22 [langchain-community]
#    -------------------------------------- - 21/22 [langchain-community]
#    -------------------------------------- - 21/22 [langchain-community]
#    -------------------------------------- - 21/22 [langchain-community]
#    -------------------------------------- - 21/22 [langchain-community]
#    -------------------------------------- - 21/22 [langchain-community]
#    -------------------------------------- - 21/22 [langchain-community]
#    -------------------------------------- - 21/22 [langchain-community]
#    -------------------------------------- - 21/22 [langchain-community]
#    -------------------------------------- - 21/22 [langchain-community]
#    -------------------------------------- - 21/22 [langchain-community]
#    -------------------------------------- - 21/22 [langchain-community]
#    -------------------------------------- - 21/22 [langchain-community]
#    -------------------------------------- - 21/22 [langchain-community]
#    -------------------------------------- - 21/22 [langchain-community]
#    -------------------------------------- - 21/22 [langchain-community]
#    -------------------------------------- - 21/22 [langchain-community]
#    -------------------------------------- - 21/22 [langchain-community]
#    -------------------------------------- - 21/22 [langchain-community]
#    -------------------------------------- - 21/22 [langchain-community]
#    -------------------------------------- - 21/22 [langchain-community]
#    -------------------------------------- - 21/22 [langchain-community]
#    -------------------------------------- - 21/22 [langchain-community]
#    -------------------------------------- - 21/22 [langchain-community]
#    -------------------------------------- - 21/22 [langchain-community]
#    -------------------------------------- - 21/22 [langchain-community]
#    -------------------------------------- - 21/22 [langchain-community]
#    -------------------------------------- - 21/22 [langchain-community]
#    -------------------------------------- - 21/22 [langchain-community]
#    -------------------------------------- - 21/22 [langchain-community]
#    -------------------------------------- - 21/22 [langchain-community]
#    -------------------------------------- - 21/22 [langchain-community]
#    -------------------------------------- - 21/22 [langchain-community]
#    -------------------------------------- - 21/22 [langchain-community]
#    -------------------------------------- - 21/22 [langchain-community]
#    -------------------------------------- - 21/22 [langchain-community]
#    -------------------------------------- - 21/22 [langchain-community]
#    -------------------------------------- - 21/22 [langchain-community]
#    -------------------------------------- - 21/22 [langchain-community]
#    -------------------------------------- - 21/22 [langchain-community]
#    -------------------------------------- - 21/22 [langchain-community]
#    -------------------------------------- - 21/22 [langchain-community]
#    -------------------------------------- - 21/22 [langchain-community]
#    -------------------------------------- - 21/22 [langchain-community]
#    -------------------------------------- - 21/22 [langchain-community]
#    -------------------------------------- - 21/22 [langchain-community]
#    -------------------------------------- - 21/22 [langchain-community]
#    -------------------------------------- - 21/22 [langchain-community]
#    -------------------------------------- - 21/22 [langchain-community]
#    -------------------------------------- - 21/22 [langchain-community]
#    -------------------------------------- - 21/22 [langchain-community]
#    -------------------------------------- - 21/22 [langchain-community]
#    -------------------------------------- - 21/22 [langchain-community]
#    -------------------------------------- - 21/22 [langchain-community]
#    -------------------------------------- - 21/22 [langchain-community]
#    -------------------------------------- - 21/22 [langchain-community]
#    -------------------------------------- - 21/22 [langchain-community]
#    -------------------------------------- - 21/22 [langchain-community]
#    -------------------------------------- - 21/22 [langchain-community]
#    -------------------------------------- - 21/22 [langchain-community]
#    -------------------------------------- - 21/22 [langchain-community]
#    ---------------------------------------- 22/22 [langchain-community]
#
# Successfully installed SQLAlchemy-2.0.48 aiohappyeyeballs-2.6.1 aiohttp-3.13.3 aiosignal-1.4.0 async-timeout-4.0.3 attrs-25.4.0 dataclasses-json-0.6.7 frozenlist-1.8.0 greenlet-3.3.2 httpx-sse-0.4.3 langchain-classic-1.0.2 langchain-community-0.4.1 langchain-core-1.2.17 langchain-text-splitters-1.1.1 marshmallow-3.26.2 multidict-6.7.1 mypy-extensions-1.1.0 numpy-2.2.6 propcache-0.4.1 pydantic-settings-2.13.1 typing-inspect-0.9.0 yarl-1.23.0
# '인프런에는 다양한 분야의 강의가 준비되어 있습니다. 주요 카테고리는 다음과 같습니다:\n\n1. **프로그래밍**: Python, Java, JavaScript, HTML/CSS, 웹 개발, 모바일 개발, 데이터베이스, 알고리즘 등 다양한 프로그래밍 언어와 주제를 다룹니다.\n\n2. **데이터 사이언스**: Python을 활용한 데이터 분석, 머신러닝, 딥러닝, 데이터 시각화, 데이터베이스 등을 학습할 수 있습니다.\n\n3. **디자인**: UI/UX 디자인, 웹 디자인, 그래픽 디자인, 브랜드 디자인 등 다양한 디자인 관련 강의가 있습니다.\n\n4. **네트워킹**: 네트워크 기초, 보안, 클라우드 컴퓨팅, 네트워크 관리 등 네트워크 관련 주제를 다룹니다.\n\n5. **인프라**: 서버 관리, 클라우드 서비스(AWS, GCP, Azure 등), 컨테이너 기술(Docker, Kubernetes) 등에 대한 강의가 있습니다.\n\n6. **비즈니스**: 프로젝트 관리, 소프트웨어 개발 방법론, 소프트웨어 아키텍처, 비즈니스 인텔리전스 등을 배울 수 있습니다.\n\n7. **기타**: 영상 편집, 오디오 편집, 문서 작성, 프레젠테이션 등 다양한 실무 기술이 포함되어 있습니다.\n\n인프런은 지속적으로 새로운 강의를 추가하고 있으므로, 관심 있는 분야의 최신 강의를 확인할 수 있습니다.'
