# %%
# %pip install python-dotenv langchain-upstage

# %%
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
import os
from langchain_upstage import ChatUpstage

llm = ChatUpstage(api_key=os.getenv("UPSTAGE_API_KEY"))
ai_message = llm.invoke("인프런에 어떤 강의가 있나요?")
ai_message.content
# Out:
# '인프런에는 다양한 분야의 강의가 제공됩니다. 주요 카테고리는 다음과 같습니다:\n\n1. **프로그래밍**: \n   - 웹 개발: HTML, CSS, JavaScript, Node.js, React, Vue.js, Angular 등\n   - 모바일 개발: Android, iOS, Flutter 등\n   - 데이터베이스: SQL, NoSQL, 데이터베이스 설계 등\n   - 네트워크: 네트워크 기초, 보안 등\n   - 시스템 프로그래밍: C, C++, Python 등\n   - 인공지능: 머신러닝, 딥러닝, TensorFlow, PyTorch 등\n\n2. **디자인**:\n   - UI/UX 디자인: Sketch, Figma 등\n   - 그래픽 디자인: Photoshop, Illustrator 등\n   - 비디오 편집: Premiere Pro, After Effects 등\n\n3. **데이터 분석**:\n   - 데이터 분석: Python, R, SQL 등\n   - 빅데이터: Hadoop, Spark 등\n   - 데이터 시각화: Tableau, Power BI 등\n\n4. **경영 및 비즈니스**:\n   - 비즈니스 모델: 스타트업, 기업가 정신 등\n   - 마케팅: 디지털 마케팅, SEO, SNS 마케팅 등\n   - 재무: 회계, 금융 등\n\n5. **기타**:\n   - 영어: 프로그래밍 영어, 비즈니스 영어 등\n   - 자기계발: 시간 관리, 목표 설정 등\n   - 취미: 요리, 음악, 미술 등\n\n이외에도 많은 분야의 강의가 있으며, 특정 주제에 대한 강의는 검색 기능을 통해 더욱 자세히 알아볼 수 있습니다. 인프런은 지속적으로 새로운 강의가 추가되므로, 관심 있는 주제의 최신 강의를 찾아볼 수 있습니다.'
